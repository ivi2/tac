# %% [markdown]
# # Analyse frequency distribution of words

# %% [markdown]
# ## Installation des dépendences

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\itiaw\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Création d'une liste de stopwords

# %%
from nltk.corpus import stopwords

sw = stopwords.words("french")
sw += ["les", "plus", "cette", "fait", "faire", "être", "deux", "comme", "dont", "tout", 
       "ils", "bien", "sans", "peut", "tous", "après", "ainsi", "donc", "cet", "sous",
       "celle", "entre", "encore", "toutes", "pendant", "moins", "dire", "cela", "non",
       "faut", "trois", "aussi", "dit", "avoir", "doit", "contre", "depuis", "autres",
       "van", "het", "autre", "jusqu"]
sw = set(sw)

# %%
print(f"{len(sw)} stopwords used: {sorted(sw)}")
# Out:
# 197 stopwords used: ['ai', 'aie', 'aient', 'aies', 'ainsi', 'ait', 'après', 'as', 'au', 'aura', 'aurai', 'auraient', 'aurais', 'aurait', 'auras', 'aurez', 'auriez', 'aurions', 'aurons', 'auront', 'aussi', 'autre', 'autres', 'aux', 'avaient', 'avais', 'avait', 'avec', 'avez', 'aviez', 'avions', 'avoir', 'avons', 'ayant', 'ayante', 'ayantes', 'ayants', 'ayez', 'ayons', 'bien', 'c', 'ce', 'cela', 'celle', 'ces', 'cet', 'cette', 'comme', 'contre', 'd', 'dans', 'de', 'depuis', 'des', 'deux', 'dire', 'dit', 'doit', 'donc', 'dont', 'du', 'elle', 'en', 'encore', 'entre', 'es', 'est', 'et', 'eu', 'eue', 'eues', 'eurent', 'eus', 'eusse', 'eussent', 'eusses', 'eussiez', 'eussions', 'eut', 'eux', 'eûmes', 'eût', 'eûtes', 'faire', 'fait', 'faut', 'furent', 'fus', 'fusse', 'fussent', 'fusses', 'fussiez', 'fussions', 'fut', 'fûmes', 'fût', 'fûtes', 'het', 'il', 'ils', 'j', 'je', 'jusqu', 'l', 'la', 'le', 'les', 'leur', 'lui', 'm', 'ma', 'mais', 'me', 'mes', 'moi', 'moins', 'mon', 'même', 'n', 'ne', 'non', 'nos', 'notre', 'nous', 'on', 'ont', 'ou', 'par', 'pas', 'pendant', 'peut', 'plus', 'pour', 'qu', 'que', 'qui', 's', 'sa', 'sans', 'se', 'sera', 'serai', 'seraient', 'serais', 'serait', 'seras', 'serez', 'seriez', 'serions', 'serons', 'seront', 'ses', 'soient', 'sois', 'soit', 'sommes', 'son', 'sont', 'sous', 'soyez', 'soyons', 'suis', 'sur', 't', 'ta', 'te', 'tes', 'toi', 'ton', 'tous', 'tout', 'toutes', 'trois', 'tu', 'un', 'une', 'van', 'vos', 'votre', 'vous', 'y', 'à', 'étaient', 'étais', 'était', 'étant', 'étante', 'étantes', 'étants', 'étiez', 'étions', 'été', 'étée', 'étées', 'étés', 'êtes', 'être']

# %% [markdown]
# ## Visualiser les termes les plus fréquents

# %%
path = "../data/all.txt"
limit = 10**8

with open(path, encoding='latin-1') as f:
    text = f.read()[:limit]

# %%
# détecter les mots
words = nltk.wordpunct_tokenize(text)
print(f"{len(words)} words found")
# Out:
# 27890820 words found

# %%
words[:10]
# Out:
# ['V', 'I', 'L', 'L', 'E', 'DE', 'BRUXELLES', 'bulletin', 'ires', '8Ã']

# %%
kept = [w.lower() for w in words if len(w) > 2 and w.isalpha() and w.lower() not in sw]
voc = set(kept)
print(f"{len(kept)} words kept ({len(voc)} different word forms)")
# Out:
# 6604846 words kept (134671 different word forms)

# %%
fdist = nltk.FreqDist(kept)
fdist.most_common(27890820)
# Out:
# [('rue', 63154),
#  ('prã', 56493),
#  ('conseil', 44628),
#  ('ville', 43557),
#  ('francs', 43452),
#  ('collã', 38130),
#  ('section', 28698),
#  ('ãªtre', 27108),
#  ('bruxelles', 27089),
#  ('art', 26224),
#  ('bourgmestre', 24845),
#  ('travaux', 22872),
#  ('administration', 21208),
#  ('rapport', 20853),
#  ('intã', 18805),
#  ('annã', 16812),
#  ('crã', 16753),
#  ('messieurs', 16415),
#  ('demande', 15434),
#  ('hospices', 15295),
#  ('question', 15138),
#  ('frais', 14997),
#  ('aprã', 14874),
#  ('mãªme', 14732),
#  ('echevin', 14700),
#  ('service', 14680),
#  ('tre', 14586),
#  ('ance', 14581),
#  ('somme', 13864),
#  ('communal', 13679),
#  ('prix', 13575),
#  ('penses', 13532),
#  ('tres', 12847),
#  ('avis', 12797),
#  ('projet', 12774),
#  ('place', 12686),
#  ('lieu', 12627),
#  ('finances', 12626),
#  ('partie', 12545),
#  ('propriã', 12515),
#  ('pense', 12414),
#  ('budget', 12400),
#  ('publique', 12231),
#  ('tait', 12231),
#  ('proposition', 12211),
#  ('compte', 12074),
#  ('police', 11986),
#  ('exã', 11217),
#  ('droit', 11078),
#  ('nombre', 10993),
#  ('sociã', 10886),
#  ('honorable', 10681),
#  ('trã', 9608),
#  ('res', 9592),
#  ('tel', 9543),
#  ('loi', 9434),
#  ('marchã', 9400),
#  ('considã', 9327),
#  ('publics', 9300),
#  ('point', 9238),
#  ('total', 9193),
#  ('adoptã', 8978),
#  ('terrain', 8973),
#  ('heures', 8957),
#  ('jour', 8610),
#  ('communale', 8592),
#  ('cas', 8533),
#  ('grand', 8462),
#  ('enfants', 8425),
#  ('cole', 8400),
#  ('mois', 8354),
#  ('ans', 8332),
#  ('ral', 8319),
#  ('thã', 8306),
#  ('saint', 8255),
#  ('recettes', 8219),
#  ('propose', 8162),
#  ('elles', 8154),
#  ('discussion', 8077),
#  ('part', 8056),
#  ('exercice', 7969),
#  ('eau', 7922),
#  ('celui', 7874),
#  ('procã', 7848),
#  ('ment', 7824),
#  ('commission', 7813),
#  ('toute', 7813),
#  ('membres', 7750),
#  ('entretien', 7723),
#  ('approbation', 7675),
#  ('vente', 7646),
#  ('leurs', 7629),
#  ('secours', 7625),
#  ('tat', 7601),
#  ('donner', 7588),
#  ('ordre', 7580),
#  ('subside', 7568),
#  ('avant', 7559),
#  ('ceux', 7543),
#  ('spã', 7475),
#  ('nom', 7446),
#  ('celte', 7440),
#  ('glement', 7429),
#  ('terrains', 7288),
#  ('gouvernement', 7280),
#  ('donnã', 7265),
#  ('conditions', 7224),
#  ('construction', 7195),
#  ('arrãªtã', 7116),
#  ('taire', 7073),
#  ('hui', 7052),
#  ('aujourd', 7035),
#  ('etc', 7026),
#  ('crois', 6966),
#  ('honneur', 6952),
#  ('vue', 6846),
#  ('favorable', 6647),
#  ('levã', 6643),
#  ('nouveau', 6630),
#  ('maison', 6619),
#  ('voie', 6615),
#  ('glise', 6613),
#  ('parce', 6593),
#  ('article', 6586),
#  ('mettre', 6578),
#  ('diffã', 6572),
#  ('cours', 6561),
#  ('gaz', 6551),
#  ('quartier', 6470),
#  ('rãªt', 6461),
#  ('voir', 6426),
#  ('chaque', 6405),
#  ('rues', 6380),
#  ('tablissement', 6374),
#  ('aucune', 6351),
#  ('cution', 6345),
#  ('ration', 6318),
#  ('temps', 6311),
#  ('conclusions', 6293),
#  ('cembre', 6292),
#  ('dernier', 6286),
#  ('grande', 6266),
#  ('suite', 6254),
#  ('maisons', 6248),
#  ('quelques', 6229),
#  ('concession', 6189),
#  ('chez', 6170),
#  ('charges', 6167),
#  ('mars', 6121),
#  ('autorisation', 6117),
#  ('plan', 6105),
#  ('public', 6103),
#  ('coles', 6018),
#  ('agit', 5926),
#  ('autoritã', 5898),
#  ('effet', 5867),
#  ('commune', 5863),
#  ('produit', 5857),
#  ('piã', 5852),
#  ('peu', 5848),
#  ('secrã', 5819),
#  ('personnel', 5813),
#  ('suivant', 5788),
#  ('tant', 5770),
#  ('comitã', 5739),
#  ('situation', 5738),
#  ('vote', 5722),
#  ('lettre', 5668),
#  ('rãªts', 5658),
#  ('faite', 5642),
#  ('janvier', 5599),
#  ('affaire', 5598),
#  ('porte', 5583),
#  ('chiffre', 5558),
#  ('traitement', 5533),
#  ('consã', 5516),
#  ('voitures', 5487),
#  ('savoir', 5450),
#  ('cent', 5355),
#  ('rien', 5342),
#  ('bureau', 5341),
#  ('mis', 5291),
#  ('quatre', 5268),
#  ('fabrique', 5247),
#  ('pourrait', 5204),
#  ('seulement', 5204),
#  ('bois', 5174),
#  ('travail', 5170),
#  ('premiã', 5133),
#  ('boulevard', 5126),
#  ('nouvelle', 5115),
#  ('caisse', 5105),
#  ('chef', 5097),
#  ('augmentation', 5074),
#  ('mai', 5074),
#  ('rapports', 5067),
#  ('hospice', 5048),
#  ('fois', 5022),
#  ('moyen', 5021),
#  ('rieur', 5002),
#  ('charge', 5001),
#  ('objet', 4967),
#  ('prendre', 4943),
#  ('pourra', 4938),
#  ('adjudication', 4881),
#  ('rieure', 4873),
#  ('car', 4865),
#  ('maniã', 4857),
#  ('valeur', 4830),
#  ('plusieurs', 4806),
#  ('canal', 4805),
#  ('possible', 4796),
#  ('alors', 4786),
#  ('premier', 4768),
#  ('quand', 4757),
#  ('proposer', 4740),
#  ('supplã', 4735),
#  ('classe', 4733),
#  ('aucun', 4708),
#  ('date', 4700),
#  ('etat', 4685),
#  ('toujours', 4681),
#  ('portã', 4662),
#  ('personnes', 4646),
#  ('reã', 4625),
#  ('octobre', 4624),
#  ('reprã', 4623),
#  ('sentã', 4610),
#  ('faã', 4609),
#  ('payer', 4607),
#  ('observations', 4568),
#  ('laquelle', 4557),
#  ('septembre', 4552),
#  ('accord', 4541),
#  ('reste', 4535),
#  ('ordinaires', 4524),
#  ('taxe', 4521),
#  ('examen', 4487),
#  ('constructions', 4478),
#  ('faites', 4435),
#  ('derniã', 4427),
#  ('population', 4412),
#  ('quant', 4388),
#  ('haute', 4378),
#  ('employã', 4371),
#  ('libã', 4355),
#  ('devant', 4347),
#  ('supã', 4340),
#  ('senne', 4335),
#  ('doivent', 4330),
#  ('communes', 4318),
#  ('cahier', 4306),
#  ('raison', 4296),
#  ('eaux', 4284),
#  ('opã', 4274),
#  ('justice', 4271),
#  ('novembre', 4266),
#  ('tablir', 4257),
#  ('ves', 4254),
#  ('fer', 4251),
#  ('jean', 4216),
#  ('beaucoup', 4208),
#  ('fonds', 4207),
#  ('avril', 4193),
#  ('systã', 4190),
#  ('cessaire', 4170),
#  ('jours', 4151),
#  ('solution', 4133),
#  ('enseignement', 4132),
#  ('juin', 4126),
#  ('centimes', 4124),
#  ('divers', 4123),
#  ('droits', 4107),
#  ('demandã', 4099),
#  ('moment', 4099),
#  ('voix', 4096),
#  ('juillet', 4083),
#  ('espã', 4068),
#  ('impã', 4059),
#  ('acte', 4023),
#  ('mesure', 4012),
#  ('peuvent', 3992),
#  ('cinq', 3988),
#  ('pouvoir', 3984),
#  ('permanente', 3971),
#  ('sieur', 3962),
#  ('proposã', 3945),
#  ('trouve', 3919),
#  ('compagnie', 3919),
#  ('ensemble', 3918),
#  ('mot', 3912),
#  ('cependant', 3865),
#  ('nature', 3855),
#  ('walravens', 3849),
#  ('posã', 3841),
#  ('chose', 3835),
#  ('trop', 3834),
#  ('assez', 3824),
#  ('pauvres', 3815),
#  ('diverses', 3815),
#  ('vrier', 3814),
#  ('aoã', 3790),
#  ('instruction', 3790),
#  ('celles', 3787),
#  ('lorsque', 3774),
#  ('taient', 3757),
#  ('sente', 3755),
#  ('richald', 3754),
#  ('royal', 3753),
#  ('ressources', 3749),
#  ('galement', 3739),
#  ('concours', 3739),
#  ('division', 3737),
#  ('membre', 3726),
#  ('six', 3724),
#  ('donne', 3713),
#  ('communales', 3710),
#  ('indemnitã', 3708),
#  ('complã', 3698),
#  ('excã', 3666),
#  ('mesures', 3651),
#  ('vient', 3646),
#  ('disposition', 3639),
#  ('cause', 3635),
#  ('bienfaisance', 3635),
#  ('courant', 3633),
#  ('accordã', 3626),
#  ('heure', 3616),
#  ('votã', 3598),
#  ('quence', 3592),
#  ('compris', 3585),
#  ('services', 3583),
#  ('corps', 3579),
#  ('location', 3575),
#  ('demander', 3561),
#  ('concessionnaire', 3553),
#  ('anspach', 3545),
#  ('approuvã', 3543),
#  ('ici', 3540),
#  ('fixã', 3536),
#  ('rer', 3531),
#  ('dix', 3520),
#  ('devoir', 3519),
#  ('nouvelles', 3503),
#  ('placã', 3474),
#  ('habitants', 3460),
#  ('situã', 3456),
#  ('extraordinaires', 3452),
#  ('ministre', 3449),
#  ('cessitã', 3421),
#  ('matã', 3378),
#  ('quelque', 3375),
#  ('emprunt', 3371),
#  ('rentes', 3370),
#  ('coã', 3361),
#  ('legs', 3355),
#  ('amã', 3354),
#  ('directeur', 3336),
#  ('pital', 3315),
#  ('allard', 3315),
#  ('seul', 3308),
#  ('cessaires', 3289),
#  ('soumis', 3274),
#  ('jamais', 3269),
#  ('chargã', 3263),
#  ('appel', 3263),
#  ('parc', 3250),
#  ('but', 3245),
#  ('dispositions', 3242),
#  ('pris', 3239),
#  ('contrat', 3236),
#  ('putation', 3202),
#  ('titre', 3200),
#  ('agents', 3187),
#  ('chemin', 3185),
#  ('midi', 3182),
#  ('entrã', 3171),
#  ('rable', 3170),
#  ('vers', 3169),
#  ('rence', 3160),
#  ('rale', 3157),
#  ('concerne', 3152),
#  ('sections', 3141),
#  ('sujet', 3124),
#  ('faits', 3120),
#  ('capital', 3118),
#  ('immã', 3116),
#  ('pain', 3112),
#  ('afin', 3111),
#  ('propositions', 3111),
#  ('plans', 3109),
#  ('voici', 3105),
#  ('hommes', 3103),
#  ('rations', 3089),
#  ('principe', 3077),
#  ('cision', 3059),
#  ('action', 3058),
#  ('montant', 3056),
#  ('dits', 3045),
#  ('renvoi', 3029),
#  ('actes', 3014),
#  ('taires', 3006),
#  ('pierre', 2985),
#  ('bon', 2980),
#  ('puis', 2980),
#  ('millions', 2974),
#  ('suivants', 2972),
#  ('cimetiã', 2971),
#  ('adressã', 2963),
#  ('mise', 2952),
#  ('payã', 2952),
#  ('ailleurs', 2948),
#  ('inconvã', 2930),
#  ('personne', 2921),
#  ('lorsqu', 2916),
#  ('destinã', 2912),
#  ('royale', 2908),
#  ('carrã', 2892),
#  ('obtenir', 2888),
#  ('nouveaux', 2884),
#  ('admis', 2873),
#  ('sident', 2866),
#  ('concessions', 2865),
#  ('sultat', 2853),
#  ('sainte', 2848),
#  ('pouvons', 2842),
#  ('remboursement', 2840),
#  ('domicile', 2839),
#  ('remarquer', 2820),
#  ('huit', 2818),
#  ('bulletin', 2815),
#  ('autorisã', 2810),
#  ('der', 2805),
#  ('suppression', 2804),
#  ('lecture', 2789),
#  ('contentieux', 2789),
#  ('termes', 2787),
#  ('fontainas', 2787),
#  ('mieux', 2775),
#  ('lors', 2773),
#  ('dent', 2771),
#  ('observation', 2768),
#  ('commerce', 2765),
#  ('connaã', 2762),
#  ('biens', 2737),
#  ('indiquã', 2736),
#  ('terminã', 2733),
#  ('autant', 2730),
#  ('obligations', 2729),
#  ('actuellement', 2727),
#  ('avenue', 2712),
#  ('idã', 2712),
#  ('paiement', 2692),
#  ('trouvã', 2691),
#  ('ancien', 2691),
#  ('passã', 2688),
#  ('pourquoi', 2686),
#  ('articles', 2683),
#  ('opinion', 2683),
#  ('watteeu', 2679),
#  ('rement', 2678),
#  ('mie', 2676),
#  ('chaussã', 2665),
#  ('devons', 2664),
#  ('vauthier', 2661),
#  ('contraire', 2660),
#  ('fera', 2660),
#  ('utilitã', 2657),
#  ('sent', 2651),
#  ('dessus', 2647),
#  ('province', 2647),
#  ('prochaine', 2642),
#  ('certain', 2631),
#  ('impossible', 2629),
#  ('clairage', 2622),
#  ('abord', 2620),
#  ('largeur', 2618),
#  ('comptes', 2616),
#  ('forme', 2614),
#  ('terre', 2613),
#  ('communication', 2606),
#  ('enfin', 2606),
#  ('surtout', 2596),
#  ('grã', 2594),
#  ('matiã', 2591),
#  ('entreprise', 2589),
#  ('outre', 2587),
#  ('examiner', 2585),
#  ('orts', 2573),
#  ('semble', 2568),
#  ('environ', 2563),
#  ('anderlecht', 2562),
#  ('moyenne', 2561),
#  ('frã', 2560),
#  ('distribution', 2554),
#  ('sulte', 2548),
#  ('voter', 2538),
#  ('tableau', 2535),
#  ('garde', 2526),
#  ('cour', 2523),
#  ('veut', 2516),
#  ('local', 2515),
#  ('arts', 2515),
#  ('ouvriers', 2513),
#  ('acquisition', 2512),
#  ('occasion', 2500),
#  ('pensions', 2493),
#  ('indigents', 2488),
#  ('partir', 2458),
#  ('devront', 2457),
#  ('adoption', 2456),
#  ('secret', 2453),
#  ('convention', 2442),
#  ('rendre', 2442),
#  ('numã', 2442),
#  ('guã', 2428),
#  ('telle', 2428),
#  ('modifications', 2424),
#  ('dame', 2411),
#  ('seule', 2410),
#  ('lequel', 2406),
#  ('diatement', 2404),
#  ('locaux', 2400),
#  ('actuel', 2399),
#  ('suit', 2392),
#  ('allocation', 2391),
#  ('alignement', 2389),
#  ('expã', 2388),
#  ('tablissements', 2387),
#  ('chiffres', 2385),
#  ('vement', 2384),
#  ('bas', 2383),
#  ('faisant', 2375),
#  ('places', 2373),
#  ('chapitre', 2372),
#  ('publiques', 2365),
#  ('exploitation', 2362),
#  ('certaines', 2361),
#  ('acadã', 2359),
#  ('placement', 2359),
#  ('parfaitement', 2359),
#  ('choses', 2358),
#  ('faveur', 2350),
#  ('mãªmes', 2349),
#  ('delã', 2348),
#  ('chacun', 2348),
#  ('pulture', 2345),
#  ('gard', 2341),
#  ('ficit', 2333),
#  ('font', 2326),
#  ('bonne', 2314),
#  ('centiares', 2311),
#  ('notaire', 2306),
#  ('conformã', 2298),
#  ('impasse', 2296),
#  ('puisse', 2293),
#  ('tabli', 2291),
#  ('certains', 2290),
#  ('argent', 2283),
#  ('ligne', 2281),
#  ('opold', 2280),
#  ('emplacement', 2276),
#  ('revenu', 2276),
#  ('recette', 2274),
#  ('renseignements', 2274),
#  ('suivante', 2273),
#  ('palais', 2264),
#  ('lai', 2261),
#  ('moyens', 2261),
#  ('fin', 2259),
#  ('avenir', 2259),
#  ('puisque', 2258),
#  ('senter', 2257),
#  ('existe', 2249),
#  ('devra', 2244),
#  ('pitaux', 2241),
#  ('objets', 2238),
#  ('sents', 2236),
#  ('duction', 2233),
#  ('usage', 2232),
#  ('signã', 2226),
#  ('charger', 2226),
#  ('sens', 2225),
#  ('fort', 2222),
#  ('sorte', 2219),
#  ('pourront', 2218),
#  ('taxes', 2216),
#  ('beaux', 2214),
#  ('monnaie', 2208),
#  ('doute', 2205),
#  ('salle', 2204),
#  ('devis', 2202),
#  ('parties', 2199),
#  ('largissement', 2198),
#  ('gouts', 2196),
#  ('cidã', 2194),
#  ('sauf', 2189),
#  ('organisation', 2188),
#  ('godefroy', 2185),
#  ('unanimitã', 2182),
#  ('verbal', 2179),
#  ('entendu', 2174),
#  ('nommã', 2168),
#  ('pensã', 2167),
#  ('serve', 2167),
#  ('pompiers', 2156),
#  ('maintenant', 2156),
#  ('filles', 2155),
#  ('depaire', 2154),
#  ('poque', 2150),
#  ('quelle', 2144),
#  ('seconde', 2133),
#  ('apprã', 2126),
#  ('cuter', 2124),
#  ('relevã', 2119),
#  ('sence', 2116),
#  ('ordonnance', 2116),
#  ('utile', 2112),
#  ('fonctions', 2112),
#  ('paris', 2109),
#  ('soumettre', 2104),
#  ('montagne', 2099),
#  ('ares', 2093),
#  ('simple', 2085),
#  ('voies', 2084),
#  ('ensuite', 2082),
#  ('pays', 2082),
#  ('taux', 2081),
#  ('circulation', 2072),
#  ('finet', 2067),
#  ('porter', 2057),
#  ('profit', 2056),
#  ('questions', 2055),
#  ('tandis', 2048),
#  ('subsides', 2042),
#  ('capitale', 2040),
#  ('difficultã', 2036),
#  ('lever', 2032),
#  ('mentaire', 2023),
#  ('laisser', 2019),
#  ('clarã', 2014),
#  ('usine', 2013),
#  ('flandre', 2010),
#  ('abattoir', 2007),
#  ('echevins', 2006),
#  ('fabriques', 2005),
#  ('ation', 2002),
#  ('paraã', 2000),
#  ('conseillers', 1997),
#  ('classes', 1991),
#  ('communaux', 1989),
#  ('cattoir', 1989),
#  ('exemple', 1984),
#  ('immeubles', 1981),
#  ('jardin', 1980),
#  ('restauration', 1979),
#  ('lot', 1979),
#  ('durant', 1975),
#  ('neiges', 1970),
#  ('pont', 1970),
#  ('voilã', 1968),
#  ('qualitã', 1968),
#  ('quel', 1967),
#  ('centimã', 1963),
#  ('chevaux', 1962),
#  ('malades', 1960),
#  ('clã', 1950),
#  ('devait', 1949),
#  ('importance', 1946),
#  ('ciale', 1938),
#  ('cutã', 1936),
#  ('besoin', 1936),
#  ('prise', 1934),
#  ('occupã', 1928),
#  ('connaissance', 1927),
#  ('neuf', 1924),
#  ('andrã', 1922),
#  ('vis', 1919),
#  ('attention', 1918),
#  ('dant', 1915),
#  ('ouverture', 1915),
#  ('troisiã', 1904),
#  ('parmi', 1900),
#  ('longtemps', 1899),
#  ('toutefois', 1899),
#  ('clamation', 1897),
#  ('loyer', 1897),
#  ('second', 1895),
#  ('kil', 1894),
#  ('explications', 1890),
#  ('nomination', 1888),
#  ('faudrait', 1879),
#  ('circonstances', 1879),
#  ('hypothã', 1878),
#  ('officiers', 1875),
#  ('obtenu', 1872),
#  ('offre', 1871),
#  ('appartenant', 1866),
#  ('annuitã', 1866),
#  ('assainissement', 1866),
#  ('condition', 1865),
#  ('premiers', 1864),
#  ('accorder', 1861),
#  ('veuve', 1861),
#  ('erreur', 1861),
#  ('extraordinaire', 1857),
#  ('minimes', 1856),
#  ('chã', 1855),
#  ('ances', 1854),
#  ('citã', 1851),
#  ('indã', 1850),
#  ('effectuã', 1850),
#  ('comment', 1848),
#  ('direction', 1842),
#  ('prochain', 1841),
#  ('examinã', 1840),
#  ('tition', 1840),
#  ('lecteurs', 1840),
#  ('cial', 1837),
#  ('liste', 1836),
#  ('fice', 1832),
#  ('athã', 1832),
#  ('sept', 1828),
#  ('allã', 1827),
#  ('professeur', 1826),
#  ('faubourgs', 1825),
#  ('emploi', 1824),
#  ('besoins', 1823),
#  ('industrie', 1818),
#  ('pierres', 1818),
#  ('projets', 1818),
#  ('suivantes', 1810),
#  ('riel', 1810),
#  ('tanneurs', 1807),
#  ('gudule', 1806),
#  ('souvent', 1804),
#  ('devrait', 1796),
#  ('voyez', 1795),
#  ('incendie', 1794),
#  ('rents', 1794),
#  ('ons', 1791),
#  ('ordinaire', 1787),
#  ('dressã', 1786),
#  ('accepter', 1784),
#  ('laeken', 1783),
#  ('passer', 1782),
#  ('obligã', 1780),
#  ('placer', 1778),
#  ('position', 1778),
#  ('ingã', 1777),
#  ('vingt', 1776),
#  ('quantitã', 1773),
#  ('anvers', 1767),
#  ('monument', 1766),
#  ('page', 1766),
#  ('pouvait', 1764),
#  ('affaires', 1764),
#  ('arbres', 1764),
#  ('constatã', 1760),
#  ('petite', 1760),
#  ('gue', 1758),
#  ('voirie', 1758),
#  ('voulu', 1756),
#  ('brouckere', 1755),
#  ('inscription', 1754),
#  ('parole', 1754),
#  ('tenir', 1751),
#  ('entiã', 1749),
#  ('nominal', 1748),
#  ('chevin', 1746),
#  ('antã', 1745),
#  ('petit', 1745),
#  ('capitaux', 1744),
#  ('bochart', 1743),
#  ('diminution', 1740),
#  ('aliã', 1738),
#  ('franã', 1736),
#  ('timents', 1736),
#  ('appelã', 1733),
#  ('bourse', 1731),
#  ('achat', 1721),
#  ('matin', 1717),
#  ('boulevards', 1716),
#  ('absolument', 1714),
#  ('contrã', 1712),
#  ('assurer', 1712),
#  ('moyennant', 1710),
#  ('moitiã', 1710),
#  ('architecte', 1705),
#  ('application', 1703),
#  ('chevins', 1703),
#  ('mille', 1702),
#  ('affectã', 1701),
#  ('relative', 1699),
#  ('construire', 1696),
#  ('villes', 1694),
#  ('passage', 1692),
#  ('veldekens', 1689),
#  ('poisson', 1686),
#  ('intervention', 1685),
#  ('cambre', 1685),
#  ('monde', 1684),
#  ('tail', 1681),
#  ('exposã', 1676),
#  ('consommation', 1662),
#  ('provincial', 1660),
#  ('sultats', 1656),
#  ('vrai', 1653),
#  ('pension', 1651),
#  ('fondã', 1650),
#  ('ter', 1650),
#  ('motifs', 1646),
#  ('bureaux', 1644),
#  ('parations', 1642),
#  ('notamment', 1642),
#  ('vendre', 1640),
#  ('difficile', 1638),
#  ('fãªtes', 1636),
#  ('points', 1635),
#  ('ritã', 1635),
#  ('noms', 1634),
#  ('anciens', 1634),
#  ('uvre', 1633),
#  ('grands', 1629),
#  ('clamations', 1629),
#  ('ade', 1628),
#  ('vertu', 1625),
#  ('loin', 1624),
#  ('grandes', 1623),
#  ('dehors', 1623),
#  ('infã', 1618),
#  ('maã', 1617),
#  ('tour', 1611),
#  ('flamand', 1611),
#  ('pavage', 1608),
#  ('augmenter', 1602),
#  ('tard', 1602),
#  ('ajouter', 1601),
#  ('facultã', 1601),
#  ('territoire', 1600),
#  ('expropriation', 1599),
#  ('mission', 1594),
#  ('face', 1592),
#  ('contributions', 1591),
#  ('sablon', 1589),
#  ('ressã', 1589),
#  ('privã', 1584),
#  ('occuper', 1583),
#  ('budgets', 1582),
#  ('sais', 1581),
#  ('centrale', 1579),
#  ('trouver', 1578),
#  ('passe', 1575),
#  ('belgique', 1573),
#  ('universitã', 1573),
#  ('quoi', 1571),
#  ('trappeniers', 1570),
#  ('cession', 1567),
#  ('lepage', 1565),
#  ('recevoir', 1564),
#  ('hygiã', 1563),
#  ('doucet', 1562),
#  ('possã', 1558),
#  ('mode', 1553),
#  ('catã', 1550),
#  ('dois', 1550),
#  ('tement', 1549),
#  ('relatif', 1542),
#  ('modification', 1539),
#  ('nient', 1537),
#  ('ferme', 1535),
#  ('peine', 1534),
#  ('mentaires', 1534),
#  ('venir', 1533),
#  ('charitã', 1533),
#  ('surveillance', 1530),
#  ('conã', 1529),
#  ('obligation', 1528),
#  ('acquã', 1527),
#  ('ancienne', 1526),
#  ('totaux', 1523),
#  ('nord', 1523),
#  ('approuver', 1522),
#  ('tude', 1522),
#  ('vois', 1521),
#  ('ventes', 1518),
#  ('admettre', 1517),
#  ('appelle', 1517),
#  ('entrepreneur', 1515),
#  ('mises', 1512),
#  ('urgence', 1512),
#  ('trouvent', 1510),
#  ('famille', 1509),
#  ('transformation', 1507),
#  ('lemaieur', 1507),
#  ('ecole', 1506),
#  ('entrepã', 1503),
#  ('tarif', 1500),
#  ('actuelle', 1496),
#  ('double', 1494),
#  ('sollicite', 1494),
#  ('monsieur', 1492),
#  ('station', 1490),
#  ('sire', 1488),
#  ('tudes', 1484),
#  ('juste', 1484),
#  ('conseiller', 1482),
#  ('mots', 1482),
#  ('terme', 1477),
#  ('bischoffsheim', 1476),
#  ('lacomblã', 1473),
#  ('haut', 1467),
#  ('primaires', 1467),
#  ('primaire', 1466),
#  ('gouverneur', 1465),
#  ('dis', 1462),
#  ('homme', 1462),
#  ('autoriser', 1462),
#  ('artistes', 1460),
#  ('gout', 1459),
#  ('enquãªte', 1457),
#  ('long', 1454),
#  ('achã', 1452),
#  ('veux', 1447),
#  ('journã', 1446),
#  ('parle', 1445),
#  ('parcelle', 1444),
#  ('quai', 1443),
#  ('trottoirs', 1438),
#  ('compã', 1437),
#  ('presque', 1436),
#  ('ouverte', 1435),
#  ('nients', 1435),
#  ('jacobs', 1433),
#  ('arriver', 1432),
#  ('appareils', 1430),
#  ('concurrence', 1429),
#  ('lesquels', 1428),
#  ('schaerbeek', 1427),
#  ('chapelle', 1424),
#  ('acquis', 1422),
#  ('tenu', 1421),
#  ('vouloir', 1420),
#  ('rente', 1417),
#  ('adhã', 1416),
#  ('caractã', 1415),
#  ('tielemans', 1411),
#  ('change', 1409),
#  ('maladies', 1409),
#  ('ajournement', 1403),
#  ('ixelles', 1402),
#  ('renvoyã', 1400),
#  ('rendu', 1399),
#  ('funck', 1398),
#  ('chauffage', 1393),
#  ('maintenir', 1391),
#  ('reconnaã', 1390),
#  ('josse', 1390),
#  ('agrã', 1389),
#  ('catherine', 1386),
#  ('vanderlinden', 1384),
#  ('sion', 1378),
#  ('roi', 1377),
#  ('lots', 1376),
#  ('civique', 1374),
#  ('proposons', 1373),
#  ('livrã', 1371),
#  ('particuliers', 1368),
#  ('magasin', 1366),
#  ('signalã', 1365),
#  ('riaux', 1364),
#  ('traitements', 1364),
#  ('servir', 1363),
#  ('arriã', 1361),
#  ('voudrais', 1360),
#  ('amortissement', 1357),
#  ('oui', 1357),
#  ('constater', 1357),
#  ('marchandises', 1357),
#  ('pondre', 1356),
#  ('viens', 1355),
#  ('libertã', 1352),
#  ('louise', 1351),
#  ('pavã', 1351),
#  ('esl', 1349),
#  ('portant', 1348),
#  ('permettre', 1344),
#  ('engagã', 1343),
#  ('yseux', 1342),
#  ('extã', 1340),
#  ('mal', 1339),
#  ('gues', 1338),
#  ('splingard', 1337),
#  ('exposition', 1336),
#  ('marche', 1333),
#  ('ministã', 1332),
#  ('delecosse', 1332),
#  ('commissaire', 1331),
#  ('gheude', 1330),
#  ('pourraient', 1328),
#  ...]

# %%
fdist.plot(50, cumulative=True)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Cumulative Counts'>

# %%
# Impression des mots qui n'apparaissent qu'une fois dans le corpus
fdist.hapaxes()[:10]
# Out:
# ['anas',
#  'enraisonde',
#  'bieniã',
#  'eldeseiã',
#  'dtput',
#  'phonnenr',
#  'umsderb',
#  'dow',
#  'iraocs',
#  'espourvica']

# %%
long_words = [w for w in voc if len(w) >= 13]
sorted(long_words)[:]
# Out:
# ['aainassijqcia',
#  'aapprovisionnements',
#  'aargbmiestfre',
#  'aatjffiderleschiffres',
#  'aauiossiiqeio',
#  'abaissesement',
#  'abandonnaient',
#  'abandonnassent',
#  'abandonnement',
#  'abandonnements',
#  'abandonneraient',
#  'abandonnerait',
#  'abandonnerions',
#  'abandonnerons',
#  'abandonneront',
#  'abandonnonsnous',
#  'abandonoementd',
#  'abdiqueraient',
#  'ablesarriventqueã',
#  'abolilionnistes',
#  'abonncmentannuel',
#  'aboutiriezvous',
#  'aboutissaient',
#  'aboutissantes',
#  'absenteraient',
#  'abslractivement',
#  'absolumentmalsain',
#  'absorberaient',
#  'abstiendraient',
#  'abstiendrions',
#  'abstractiveinent',
#  'accaparements',
#  'accepteraient',
#  'accessibilitã',
#  'accessoirement',
#  'accidenlellcs',
#  'accidenlelleinent',
#  'accidentellement',
#  'accidentelles',
#  'acclimatation',
#  'accoinplisscmentdcsconditionsprescritesparfart',
#  'accommodement',
#  'accommodements',
#  'accommoderaient',
#  'accomoderaient',
#  'accompagnaient',
#  'accompagnateurs',
#  'accompagnateursdesclassesde',
#  'accompagnement',
#  'accompagnements',
#  'accompagnerai',
#  'accompagneraient',
#  'accompagnerez',
#  'accompagneront',
#  'accompliraient',
#  'accomplissaient',
#  'accomplissait',
#  'accomplissant',
#  'accomplissement',
#  'accomplissementdel',
#  'accomplissent',
#  'accomplissions',
#  'accomplissment',
#  'accomplissons',
#  'acconiplisscmeul',
#  'accorderaient',
#  'accouchements',
#  'accroissemenl',
#  'accroissemens',
#  'accroissement',
#  'accroissements',
#  'accrroissement',
#  'accueilleraient',
#  'accueillerais',
#  'accueillerait',
#  'accueillericz',
#  'accueilleriez',
#  'accueillerions',
#  'accueillerons',
#  'accueilleront',
#  'accueillirent',
#  'accueillirfavorablement',
#  'accumulateurs',
#  'aceompiissement',
#  'aceomplissmeent',
#  'achatdeprovisions',
#  'achtergatstraetje',
#  'achtervolgende',
#  'achtschellinck',
#  'acidechlorhydrique',
#  'aclassification',
#  'acluelleinonl',
#  'acluellenient',
#  'acluellenienten',
#  'acquiescement',
#  'acquiescerait',
#  'acquiescetncnt',
#  'acquisitioiis',
#  'acquisitioude',
#  'acquittements',
#  'actiiellemcnt',
#  'actionintentã',
#  'actueiletnenl',
#  'actuellemeent',
#  'actuellementprostituã',
#  'addilionnelle',
#  'additionnelle',
#  'additionnelles',
#  'additionnnelle',
#  'adesratification',
#  'adiniiustration',
#  'adininislratioit',
#  'adininislration',
#  'adininistraliou',
#  'adininistration',
#  'adiriinistration',
#  'adjiiiitistrations',
#  'adjinlication',
#  'adjoindraient',
#  'adjointcommissaire',
#  'adjointechevin',
#  'adjointinspecteur',
#  'adjointscommissaires',
#  'adjointsinspecteurs',
#  'adjointsiuspecteurs',
#  'adjudantsmajors',
#  'adjudicalaire',
#  'adjudicalaires',
#  'adjudicaliori',
#  'adjudicataire',
#  'adjudicataires',
#  'adjudications',
#  'adjugerlcsstations',
#  'adjujicataires',
#  'adjurlication',
#  'admanistration',
#  'admcltreavecm',
#  'admellatitriue',
#  'admenistration',
#  'admiaistration',
#  'admidiitratir',
#  'admidistration',
#  'admidlstration',
#  'admiiiiatration',
#  'admiiiisiratton',
#  'admiiiislraiioiipa',
#  'admiiiislration',
#  'admiiiislrution',
#  'admiitistralif',
#  'admiministration',
#  'admimslralion',
#  'admimstralioii',
#  'admimstration',
#  'adminfstration',
#  'admininistratif',
#  'admininistration',
#  'adminisiralioii',
#  'adminisiralion',
#  'adminisiraliort',
#  'adminisiraliou',
#  'adminisiralive',
#  'adminisiratifs',
#  'adminisiration',
#  'adminisirotion',
#  'adminisirtition',
#  'adminislialion',
#  'adminisliation',
#  'adminislrabon',
#  'adminislraiion',
#  'adminislraleur',
#  'adminislralioii',
#  'adminislralion',
#  'adminislralions',
#  'adminislralive',
#  'adminislration',
#  'adminislrationde',
#  'adminislratiub',
#  'adminislrativement',
#  'adminislretion',
#  'adminislrjilioo',
#  'adminislrtilion',
#  'adminisration',
#  'administation',
#  'administatives',
#  'administeation',
#  'administiatioa',
#  'administiation',
#  'administraarriver',
#  'administradon',
#  'administrafion',
#  'administraiion',
#  'administraion',
#  'administraive',
#  'administrajion',
#  'administraleur',
#  'administralifs',
#  'administralion',
#  'administralions',
#  'administralivcment',
#  'administralivement',
#  'administratenr',
#  'administrateur',
#  'administrateurdirecteur',
#  'administrateurinspecteur',
#  'administrateurs',
#  'administratic',
#  'administratien',
#  'administratif',
#  'administratifd',
#  'administratifiii',
#  'administratifs',
#  'administratio',
#  'administratioii',
#  'administration',
#  'administrationcommunale',
#  'administrationdes',
#  'administrationjdes',
#  'administrationpgã',
#  'administrations',
#  'administrationsqui',
#  'administratioq',
#  'administratiorts',
#  'administratiou',
#  'administratirement',
#  'administrative',
#  'administrativement',
#  'administratives',
#  'administrativeâ',
#  'administratiã',
#  'administratration',
#  'administratton',
#  'administrerais',
#  'administrerait',
#  'administrerez',
#  'administretion',
#  'administrnlifs',
#  'administrrlion',
#  'adminitration',
#  'adminjstration',
#  'adminstration',
#  'adminstrations',
#  'admiobtration',
#  'admioistration',
#  'admiolstration',
#  'admirablement',
#  'admirablementavecceluidesintã',
#  'admirahlenienl',
#  'admirdslration',
#  'admiristration',
#  'admirnstration',
#  'admirristration',
#  'admisensubsistance',
#  'admissibilitã',
#  'admistrationsmunicipales',
#  'admitiisimtioti',
#  'admiuislralif',
#  'admiuislration',
#  'admiuistialioii',
#  'admiuistralion',
#  'admiuistration',
#  'admiuistrations',
#  'admiwatratiod',
#  'admmistration',
#  'admnistration',
#  'admteisstratiobi',
#  'admtnislralion',
#  'adnfiimtration',
#  'adniinislralion',
#  'adniinistraleurs',
#  'adniinistralinn',
#  'adniinistralion',
#  'adosinistialion',
#  'adoucissement',
#  'adoucissements',
#  'adrainislralion',
#  'adrainislratioc',
#  'adrainistration',
#  'adrainistratn',
#  'adrainwtratofc',
#  'adresseraient',
#  'adrienauguste',
#  'adriendelfosse',
#  'adrninislraiions',
#  'adrninislration',
#  'adroinistrail',
#  'adroinistration',
#  'adtninistration',
#  'adtninistratã',
#  'adtninteiruuf',
#  'aduunisiralive',
#  'advaitcenient',
#  'aecidenlelles',
#  'aecroissement',
#  'aeeeuillerait',
#  'aexplications',
#  'afbrmativement',
#  'affaiblirions',
#  'affaiblissait',
#  'affaiblissement',
#  'affaiblissent',
#  'affairesfiniesou',
#  'affaissements',
#  'affecteraient',
#  'affermissement',
#  'affirmativement',
#  'affouillement',
#  'affouillements',
#  'affranchiraient',
#  'affranchirais',
#  'affranchirons',
#  'affranchiront',
#  'affranchissait',
#  'affranchissant',
#  'affranchissement',
#  'affranchissent',
#  'affranchissez',
#  'affranchissons',
#  'aflammesbleues',
#  'afllrmativement',
#  'agbflnoagibbfl',
#  'agentsfontainiers',
#  'agentsinspecteurs',
#  'agfjiiibgtattffi',
#  'agglomcralion',
#  'agglomeration',
#  'aggraveraient',
#  'agisruecoppens',
#  'agmiidissemenl',
#  'agrandismenls',
#  'agrandissaient',
#  'agrandissemeat',
#  'agrandissemen',
#  'agrandissement',
#  'agrandissementdu',
#  'agrandissements',
#  'agrandissemfint',
#  'agrandjjsemcntdc',
#  'agrardissement',
#  'agrondissemerit',
#  'aiaiabnarnobo',
#  'aiaoraoaaildblo',
#  'aichitectonique',
#  'aideschirurgicds',
#  'aidesihimisles',
#  'aidesinstitutrices',
#  'aienderplancken',
#  'aigealleinande',
#  'aiiginenlation',
#  'aiigmeatatious',
#  'aiigmentalinn',
#  'aiigmentalion',
#  'aiiiroaaoaaisijã',
#  'aiilorisalion',
#  'aiiminislralion',
#  'aiiminislration',
#  'aijrsgimcrtoo',
#  'ailbqabfljimmoo',
#  'ailmioislratioo',
#  'ailranchissement',
#  'ainortisseinã',
#  'ainsraisonnements',
#  'aiqoadlnblidq',
#  'aiseallemande',
#  'aisienderaents',
#  'aissainissement',
#  'aitranchissement',
#  'aittorisalion',
#  'ajileweireldt',
#  'ajournementde',
#  'ajuiiiiistration',
#  'alafamilleappartientnaturellementl',
#  'alexiscorneille',
#  'alfouillements',
#  'alignementcouforme',
#  'alignementetde',
#  'alignementqui',
#  'alimenteraient',
#  'alinevanderstegen',
#  'alinienlalion',
#  'aliserontdans',
#  'allenlivemeiil',
#  'allirmalivcment',
#  'allongeraient',
#  'allopathiques',
#  'alnemeaaitdbje',
#  'alnojnavnorjiii',
#  'alphonsehenri',
#  'altentivement',
#  'alternativement',
#  'alterrisscmcnts',
#  'alterrissements',
#  'ambitionnerait',
#  'ameglobalepor',
#  'ameublissement',
#  'aministralion',
#  'aministration',
#  'amoiiissemement',
#  'amoindrissaient',
#  'amoindrissait',
#  'amoindrissant',
#  'amoindrissement',
#  'amoindrissent',
#  'amoindrissons',
#  'amollissement',
#  'amoncellement',
#  'amoriissemenl',
#  'amoriissement',
#  'amorlissablcs',
#  'amorlisscmerd',
#  'amorlissemenl',
#  'amorlissement',
#  'amorlisseractit',
#  'amortirontannuellement',
#  'amortissables',
#  'amortissaient',
#  'amortissemcnl',
#  'amortissemcnt',
#  'amortissemement',
#  'amortissemenl',
#  'amortissement',
#  'amortissements',
#  'amortissemtnt',
#  'amortissoraenfeffecluã',
#  'amphibologique',
#  'amplification',
#  'anachronismes',
#  'ancefestouverte',
#  'anciennedemeure',
#  'anciennegaiedumidi',
#  'anciensemployã',
#  'anderlechtauront',
#  'anderlechtmolenbeek',
#  'anderstraeten',
#  'anfractuositã',
#  'anginenlhtion',
#  'angmentalioni',
#  'angmentatioii',
#  'angrirniiilion',
#  'angulairement',
#  'aniendeuenienl',
#  'animadvcrsion',
#  'animadversion',
#  'anlcrieurement',
#  'anlicipativement',
#  'anligaslralgiques',
#  'anlorisalions',
#  'anmoinscerlainqueces',
#  'annexionnistes',
#  'annihilissement',
#  'anniversaires',
#  'annonceraient',
#  'annonciadesjcitã',
#  'anoijbiobienoo',
#  'anoijudrijnoo',
#  'antagensesqiii',
#  'anthropologie',
#  'anthropologique',
#  'antiadministratif',
#  'anticipalivement',
#  'anticipativcment',
#  'anticipativement',
#  'anticipativementdu',
#  'anticonstitutionnel',
#  'antieipativement',
#  'antieipativenicnt',
#  'antimiasmatiques',
#  'antinationalcs',
#  'antinationale',
#  'antirationnei',
#  'antiseptiques',
#  'antoineaiuliã',
#  'antoineferdinand',
#  'antoinejoseph',
#  'aoijciiqoiqxa',
#  'aoijeaiflumnioo',
#  'aorioemnrjbri',
#  'aotibilidotami',
#  'aotimialaiinkiã',
#  'aotographique',
#  'apercevraient',
#  'aplanissement',
#  'aplatissement',
#  'appareilleurs',
#  'apparlenaienl',
#  'apparletenaient',
#  'apparliennenl',
#  'apparliennentã',
#  'appartenaient',
#  'appartiendraient',
#  'appartiendrait',
#  'appartiendront',
#  'appartiennent',
#  'appartinssent',
#  'appauvrissement',
#  'appauvrissent',
#  'appelleraient',
#  'appesantirons',
#  'applanissement',
#  'applaudissaient',
#  'applaudissait',
#  'applaudissant',
#  'applaudisscments',
#  'applaudissement',
#  'applaudissements',
#  'applaudissent',
#  'applaudisseurs',
#  'applaudissiez',
#  'applaudissons',
#  'applaulissementssont',
#  'applicabilitã',
#  'applicableaux',
#  'applicacation',
#  'applicainduirail',
#  'appliplication',
#  'appliqueraient',
#  'appliquerions',
#  'appliquerplus',
#  'appoinlemements',
#  'appoinlements',
#  'appointemenis',
#  'appointemensde',
#  'appointements',
#  'apporleraient',
#  'apporteraient',
#  'apprenlissage',
#  'apprentissage',
#  'apprentissages',
#  'approbationde',
#  'approbationdu',
#  'approbationgã',
#  'approbaventes',
#  'approfondirai',
#  'approfondissait',
#  'approfondissant',
#  'approfondissement',
#  'approfondissements',
#  'appropriables',
#  'appropriaiton',
#  'approprialion',
#  'appropriatien',
#  'appropriation',
#  'appropriations',
#  'approusionnemenl',
#  'approuvassent',
#  'approuveraient',
#  'approuverions',
#  'approuverlesactes',
#  'approvisionnaient',
#  'approvisionnait',
#  'approvisionnant',
#  'approvisionncmenl',
#  'approvisionne',
#  'approvisionnebjbnts',
#  'approvisionnem',
#  'approvisionnemens',
#  'approvisionnement',
#  'approvisionnementde',
#  'approvisionnements',
#  'approvisionnenements',
#  'approvisionnent',
#  'approvisionner',
#  'approvisionnera',
#  'approvisionnerait',
#  'approvisionneront',
#  'approvisionneur',
#  'approvisionneurs',
#  'approvisionnez',
#  'approvisionneâ',
#  'approvisionnons',
#  'approvisionnã',
#  'approvisiounement',
#  'approvisonnent',
#  'approvisonner',
#  'approximaiions',
#  'approximaiivement',
#  'approximaliment',
#  'approximalivement',
#  'approximatifs',
#  'approximation',
#  'approximations',
#  'approximativcment',
#  'approximative',
#  'approximativem',
#  'approximativement',
#  'approximatives',
#  'aprofitquipeui',
#  'aquarellistes',
#  'aqueduclarron',
#  'aqueducsjjjfj',
#  'araudageslessagerics',
#  'arbitrairement',
#  'arbolieullure',
#  'arboriculleur',
#  'arboriculteur',
#  'arboriculteurs',
#  'arboriculture',
#  'arcbilectonique',
#  'archiduchesse',
#  'archilecluralement',
#  'architectechargã',
#  'architectecte',
#  'architecteingã',
#  'architectonique',
#  'architectoniques',
#  'architectural',
#  'architecturale',
#  'architecturales',
#  'architectures',
#  'architektonischer',
#  'arcliileclure',
#  'arebitectonique',
#  'argumeiilation',
#  'argumenlalion',
#  'argumentation',
#  'argumentaujourd',
#  'aristocraties',
#  'aristocratique',
#  'aristocratiques',
#  'armandnarcisse',
#  'armorlissement',
#  'armortissement',
#  'arrandissement',
#  'arrangeraient',
#  'arrivaientles',
#  'arrondissantles',
#  'arrondisscmentde',
#  'arrondissemens',
#  'arrondissement',
#  'arrondissements',
#  'arrondissemeut',
#  'arroseinentde',
#  'arrãªteraient',
#  'articulations',
#  'artificiellement',
#  'artificielles',
#  'artistephotographe',
#  'artistesappelã',
#  'artistiquement',
#  'ascendantfefdescendant',
#  'ascendantincontestã',
#  'ascensionnelle',
#  'ascensionnels',
#  'ascentionnellc',
#  'ascentionnelle',
#  'aschaffenbourg',
#  'asminissement',
#  'aspirantsofficiers',
#  'assainiraient',
#  'assainissemant',
#  'assainissemeni',
#  'assainissement',
#  'assainissementde',
#  'assainissementdes',
#  'assainissements',
#  'assainissemer',
#  'assainissemest',
#  'assainissemont',
#  'assainisserae',
#  'assainisseraer',
#  'assainissesementet',
#  'assaisonnement',
#  'assaiuissement',
#  'assaklissemeql',
#  'assalaissement',
#  'assamissement',
#  'assentimentsans',
#  'assentiraentdu',
#  'assentissement',
#  'asservissement',
#  'assigneraient',
#  'assimilations',
#  'assimileraient',
#  'assislaiicepublitiue',
#  'assisteraient',
#  'assombrissent',
#  'assouplissant',
#  'assourdissant',
#  'assourdissantes',
#  'asstlcrlsaadeib',
#  'assujettirait',
#  'assujettissements',
#  'astreindraient',
#  'astronomiques',
#  'atalesdisereofs',
#  'atermoiements',
#  'atjininislralion',
#  'atjtoeisation',
#  'atlerrissements',
#  'atlministration',
#  'atteindraient',
#  'atteintessenticllement',
#  'attentatoires',
#  'attentivement',
#  'attermoiements',
#  'atterrissemenls',
#  'atterrissement',
#  'atterrissements',
#  'attesteraient',
#  'attribuassent',
#  'attroupements',
#  'attroupementsse',
#  'aucmemtations',
#  'aucunefissureni',
#  'aucunequestion',
#  'audacieusement',
#  'aueuneatrocitã',
#  'augfnenlation',
#  'auginenlaiiou',
#  'auginenlalion',
#  'auginentaliou',
#  'augmeiiterions',
#  'augmenialious',
#  'augmenlalioiis',
#  'augmenmedlatioq',
#  'augmentafimii',
#  'augmentalions',
#  'augmentassent',
#  'augmentasuivantes',
#  'augmentaticrh',
#  'augmentationde',
#  'augmentations',
#  'augmentationâ',
#  'augmenteraient',
#  'augmenterions',
#  'augnientalion',
#  'augnientation',
#  'augniniiaiion',
#  'augraenlalion',
#  'augraenlation',
#  'augraentatation',
#  'augrnentalion',
#  'augustejoseph',
#  'aulographiste',
#  'aulographistes',
#  'auniversaires',
#  'auraientelles',
#  'auraitenviron',
#  'auraitfinipar',
#  'auraitledroit',
#  'aurandisscnient',
#  'aurionstortde',
#  'authographier',
#  'autobiographie',
#  'autographisles',
#  'autographiste',
#  'autographistes',
#  'automatiquement',
#  'autorisasation',
#  'autorisationa',
#  'autorisationde',
#  'autorisations',
#  'autorisatiori',
#  'autorisiition',
#  'autrementeeserait',
#  'autrichehongrie',
#  'autrichiennes',
#  'auxbraconnier',
#  'auxconcurrence',
#  'auxdekeukeleer',
#  'auxderammeleer',
#  'auxdufournaux',
#  'auxeotonnettes',
#  'auxfillesprostituã',
#  'auxfillespubliques',
#  'auxfinancescommunales',
#  'auxfinancesde',
#  'auxgustenhove',
#  'auxrenseignemens',
#  'auxroarchandsde',
#  'auxvandermeere',
#  'avaitmisedans',
#  'avaitnettemenl',
#  'avanlageusenienl',
#  'avantageaient',
#  'avantagefinancier',
#  'avantageusemant',
#  'avantageusement',
#  'avecanasarque',
#  'avecdesfcoquillages',
#  'avecobligation',
#  'avenuedesarts',
#  'averlirsement',
#  'averlisscmcnts',
#  'averlissement',
#  'avertissemenl',
#  'avertissement',
#  'avertissements',
#  'avilissements',
#  'avisfavorablea',
#  'avisfavorablesur',
#  'axtbaiexnenis',
#  'aymonetdessix',
#  'ayruudissemenl',
#  'bacligeonnage',
#  'badiareonnage',
#  'badigeoiinage',
#  'badigeonnageetdes',
#  'badigeonnages',
#  'badigeonnante',
#  'bahiluellesde',
#  'bamingantisme',
#  'bamollissement',
#  'bancspupitres',
#  'banqueroutier',
#  'baplistearmand',
#  'baraquerecouvete',
#  'barrasseraient',
#  'barrasserions',
#  'baschoffeheha',
#  'bassemblements',
#  'bataillestraatman',
#  'batailloncarrã',
#  'bateaudragueur',
#  'bateauxloueurs',
#  'bateauxmouches',
#  'bateauxtoueurs',
#  'bcessionnaire',
#  'bcrgeronneltfs',
#  'beaulieuetlaveleye',
#  'becapitulation',
#  'beclificalion',
#  'beconnaissant',
#  'beconstruction',
#  'becouvrements',
#  'beekjtterbeek',
#  'beggeynenbosch',
#  'belgianpublic',
#  'bellefontaine',
#  'bemboureemeat',
#  'bemboursement',
#  'bemboursements',
#  'bemboursiement',
#  'bemhoursement',
#  'beniboursenient',
#  'benlmeesteren',
#  'benseignements',
#  'berchemsainte',
#  'bergeronnettes',
#  'besagasbasass',
#  'besoinsctavec',
#  'bestiauxcrieurs',
#  'bflschofflfelieirai',
#  'bfsrhoitshcim',
#  'biaselioflfelieim',
#  'bibliographie',
#  'bibliographique',
#  'bibliographiques',
#  'bichesclaires',
#  'bieeehofeheini',
#  'bienfaifaisance',
#  'bienfaipendant',
#  'bienfaisaiice',
#  'bienfaisaneequand',
#  'bienfaisantes',
#  'bienfaissance',
#  'bienfaissante',
#  'bienindigents',
#  'bienvcillante',
#  'bienveillance',
#  'bienveillante',
#  'bienveillantes',
#  'bienveillants',
#  'bienvetilimte',
#  'biicholfsjieim',
#  'binoclelorgnon',
#  'biscbaoffshfiua',
#  'biscbiofffslseã',
#  'biscbioffseieiua',
#  'biscbioffsheim',
#  'biscboffsbeim',
#  'biscboffshcim',
#  'biscboffsheim',
#  'biscboflsheim',
#  'biscboifsbeim',
#  'biscfaoffsclieim',
#  'bischaffsheim',
#  'bischoffisfiaeiiii',
#  'bischoffisheiin',
#  'bischoffisheim',
#  'bischoffisiiebiirb',
#  'bischoffsbcim',
#  'bischoffsbclm',
#  'bischoffsbeiin',
#  'bischoffsbeim',
#  'bischoffscheim',
#  'bischoffsfteã',
#  'bischoffshcim',
#  'bischoffshehn',
#  'bischoffshehu',
#  'bischoffsheiaia',
#  'bischoffsheiin',
#  'bischoffsheim',
#  'bischoffsheimâ',
#  'bischoffsheini',
#  'bischoffsheira',
#  'bischoffsheirn',
#  'bischoffshejm',
#  'bischoffshelm',
#  'bischoffshtiim',
#  'bischoffsiieim',
#  'bischoffskeim',
#  'bischoffskeini',
#  'bischoffslbeiiii',
#  'bischoffslieiaib',
#  'bischoffslieim',
#  'bischoffssaessn',
#  'bischoffssheim',
#  'bischoffsueiiia',
#  'bischofifsheim',
#  'bischofifshãªim',
#  'bischofimieim',
#  'bischofisheim',
#  'bischofjfsheim',
#  'bischoflfeheim',
#  'bischoflfocheim',
#  'bischoflfsbaeim',
#  'bischoflfsheim',
#  'bischoflmieim',
#  'bischoflshcim',
#  'bischoflsheim',
#  'bischoflsiicim',
#  'bischofpslbcimi',
#  'bischoftsheim',
#  'bischoftslicim',
#  'bischoifsheiffi',
#  'bischoifsheim',
#  'bischoifsheirnj',
#  'bischoiisheim',
#  'bischoiisiieini',
#  'bischoilsheim',
#  'bischoitgueiiu',
#  'bischoitsbieian',
#  'bischoitsltelim',
#  'bischoitsueim',
#  'bischojfshcim',
#  'bischojjsheim',
#  'bischolfsheim',
#  'bischolisheim',
#  'bischollsheim',
#  'bischolrsheim',
#  'bischoltpsheim',
#  'bischoltsheim',
#  'bischoltsiicibm',
#  'bischonslieim',
#  'bischottsheim',
#  'bischuffsheim',
#  'bisciaesfsiieim',
#  'bisciaoitshcsni',
#  'biscibofpslieiim',
#  'bisciioffsheim',
#  'bisciiofifctieiifii',
#  'bisciiofitsiieim',
#  'bisciioftsheiih',
#  'biscisostsiicim',
#  'biscisottslsesm',
#  'biscjhoffsheim',
#  'bisckoffsheim',
#  'bisckoffsneim',
#  'bisckoftsiieim',
#  'bisclboatsbbeilaii',
#  'bisclfioftshcim',
#  'bisclioffsbcim',
#  'bisclioffsbeim',
#  'bisclioffshcim',
#  'bisclioffsheim',
#  'bisclioffskeiin',
#  'bisclioffslieim',
#  'bisclioflfeheim',
#  'biscliofpsfcessn',
#  'bisclioftsiaeã',
#  'bisclioftsucim',
#  'bisclioitssiicini',
#  'bisclwffsheim',
#  'biscnoffsheim',
#  'biscsaostslaesaib',
#  'biscstoflfsheini',
#  'biscttoffsheim',
#  'biscuoffsheim',
#  'bisdioffsheim',
#  'biseboffsbeim',
#  'bisefcofirssscin',
#  'bisehoffshcira',
#  'bisehoffsheim',
#  'bisehoffsheira',
#  'bisehoffsiiciui',
#  'bisehofivheim',
#  'bisehoifshcim',
#  'biseholfsheim',
#  'bisekosskeini',
#  'biseliolfslieim',
#  'bisohoflfsbenoa',
#  'bisschoffeheim',
#  'bisschoffheim',
#  'bisschoffshcim',
#  'bisschoffsheim',
#  'bisschoffsheira',
#  'bisschoffsheirci',
#  'bisschoflfalieim',
#  'bisschoflsheim',
#  'bisschofsheim',
#  ...]
